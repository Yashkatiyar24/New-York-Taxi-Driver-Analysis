# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.5 MB 7.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.5 MB 7.7 MB/s eta 0:00:02
#    --------------- ------------------------ 4.5/11.5 MB 7.2 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/11.5 MB 7.1 MB/s eta 0:00:01
#    -------------------------- ------------- 7.6/11.5 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 7.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
# !pip install pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#     --------------------------------------- 0.5/25.1 MB 2.1 MB/s eta 0:00:12
#    -- ------------------------------------- 1.6/25.1 MB 2.9 MB/s eta 0:00:09
#    --- ------------------------------------ 2.4/25.1 MB 3.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.6/25.1 MB 2.7 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.4/25.1 MB 2.7 MB/s eta 0:00:09
#    ------ --------------------------------- 4.2/25.1 MB 2.8 MB/s eta 0:00:08
#    -------- ------------------------------- 5.2/25.1 MB 3.0 MB/s eta 0:00:07
#    -------- ------------------------------- 5.5/25.1 MB 3.0 MB/s eta 0:00:07
#    --------- ------------------------------ 6.0/25.1 MB 2.8 MB/s eta 0:00:07
#    ---------- ----------------------------- 6.8/25.1 MB 2.8 MB/s eta 0:00:07
# ...

# %%
# !pip install fastparquet
# Out:
# ...
#    ---------------------------------------- 0.0/673.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/673.0 kB ? eta -:--:--
#    ------------------------------- -------- 524.3/673.0 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 673.0/673.0 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 2.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 2.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 1.8 MB/s eta 0:00:00
# ...

# %%
taxi_df = pd.read_parquet(r"C:\Users\anshk\New-York-Taxi-Driver-Analysis\Data\yellow_tripdata_2019-07.parquet")

# %%
taxi_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2019-07-01 00:51:04   2019-07-01 00:51:33              1.0
# 1         2  2019-07-01 00:46:04   2019-07-01 01:05:46              1.0
# 2         1  2019-07-01 00:25:09   2019-07-01 01:00:56              1.0
# 3         2  2019-07-01 00:33:32   2019-07-01 01:15:27              1.0
# 4         1  2019-07-01 00:00:55   2019-07-01 00:13:05              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.00         1.0                  N           193           193
# 1           4.16         1.0                  N           234            25
# 2          18.80         2.0                  N           132            42
# 3          18.46         2.0                  N           132           142
# 4           1.70         1.0                  N           107           114
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
taxi_df.shape
# Out:
# (6310419, 19)
